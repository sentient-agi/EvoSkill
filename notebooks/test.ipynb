# %%
from src.evaluation import score_answer
import pickle as pkl
import pandas as pd

# original_df = pd.read_csv("../.dataset/new_runs_evolved/train_set.csv")
with open('../results/opus_train05_val_07_28iters.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
train_set = {
    'question': [],
    'index': [],
    'predicted': [],
    'ground_truth': [],
    'score_0.05': [],
    'score_0.01': [],
    'score_0.1': [],
    'score_0.0': [],
    'score_0.025': [],
    'final_score': []
}

# %%
for set_index, example in enumerate(data):
    try:
        question = example.question
        index = example.index
        ground_truth = example.ground_truth
        predicted = example.trace.output.final_answer
        final_score = 0.0
        for tolerance in [0.05, 0.01, 0.1, 0.0, 0.025]:
            score = score_answer(ground_truth=ground_truth, predicted=predicted, tolerance=tolerance)
            train_set[f'score_{tolerance}'].append(score)
            final_score += score
        final_score /= 5.0
        train_set['final_score'].append(final_score)
        train_set['question'].append(question)
        train_set['index'].append(index)
        train_set['ground_truth'].append(ground_truth)
        train_set['predicted'].append(predicted)
    except Exception as e:
        print(f"Error processing example {index}: {e}")
        print(f"true index: {set_index}")
        continue
# Out:
# Error processing example 56: 'NoneType' object has no attribute 'final_answer'
# true index: 2
# Error processing example 146: 'NoneType' object has no attribute 'output'
# true index: 115
# Error processing example 192: 'NoneType' object has no attribute 'final_answer'
# true index: 122
# Error processing example 124: 'NoneType' object has no attribute 'final_answer'
# true index: 181
# Error processing example 7: 'NoneType' object has no attribute 'final_answer'
# true index: 184
# Error processing example 85: 'NoneType' object has no attribute 'final_answer'
# true index: 185
# Error processing example 84: 'NoneType' object has no attribute 'final_answer'
# true index: 186
# Error processing example 163: 'NoneType' object has no attribute 'final_answer'
# true index: 187
# Error processing example 202: 'NoneType' object has no attribute 'final_answer'
# true index: 188
# Error processing example 47: 'NoneType' object has no attribute 'final_answer'
# true index: 189
# ...

# %%
sum(train_set['final_score'])/len(train_set['final_score'])
# Out:
# 0.7233333333333333

# %%
sum(train_set['score_0.0'])/len(train_set['final_score'])
# Out:
# 0.6277777777777778

# %%
import numpy as np 

final_scores = np.array(train_set['final_score'])
wrong_indices = np.where(final_scores <= 0.8)
right_indices = np.where(final_scores == 1.0)

# %%
wrong_indices

# %%
train_set['question'][89]

# %%
train_set['ground_truth'][89]

# %%
train_set['predicted'][89]

# %%
len(wrong_indices[0])/len(final_scores)

# %%
len(final_scores)

# %%
original_df
